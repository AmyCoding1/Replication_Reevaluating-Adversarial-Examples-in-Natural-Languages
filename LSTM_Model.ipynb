# %%
# !mkdir /drive/MyDrive/TextAttack
# Out:
# mkdir: cannot create directory ‘/drive/MyDrive/TextAttack’: No such file or directory

# %%
# !python -m venv tf_env
# Out:
# The virtual environment was not created successfully because ensurepip is not
# available.  On Debian/Ubuntu systems, you need to install the python3-venv
# package using the following command.
#
#     apt install python3.10-venv
#
# You may need to use sudo with that command.  After installing the python3-venv
# package, recreate your virtual environment.
#
# Failing command: /content/tf_env/bin/python3

# %%
# %cd  /drive/MyDrive/TextAttack
# Out:
# [Errno 2] No such file or directory: '/drive/MyDrive/TextAttack'
# /content

# %%
# %cd TextAttack/
# Out:
# /content/TextAttack

# %%
# !git clone https://github.com/QData/TextAttack.git
# Out:
# Cloning into 'TextAttack'...
# remote: Enumerating objects: 21175, done.
# remote: Counting objects: 100% (640/640), done.
# remote: Compressing objects: 100% (349/349), done.
# remote: Total 21175 (delta 379), reused 466 (delta 288), pack-reused 20535
# Receiving objects: 100% (21175/21175), 25.87 MiB | 6.66 MiB/s, done.
# Resolving deltas: 100% (15684/15684), done.

# %%
# %cd  TextAttack

# !pip install -e .
# Out:
# Obtaining file:///content/TextAttack
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 932.9 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.2/387.2 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 36.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 43.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 MB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.4 MB/s eta 0:00:00
# ...

# %%
# !pip install .
# Out:
# Processing /content/TextAttack
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for textattack: filename=textattack-0.3.9-py3-none-any.whl size=884205 sha256=a76a784a178e0e2189edba5c452edff393c03bf6f54c45d499f2bc2f579bd478
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4rrg_v29/wheels/85/37/42/9aafc263611a7e8a02c62b15fbbd42587dd9eb98379079e4e1
# Successfully built textattack
# ...
#   Attempting uninstall: textattack
#     Found existing installation: textattack 0.3.9
#     Uninstalling textattack-0.3.9:
#       Successfully uninstalled textattack-0.3.9
# ...

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/TextAttack
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: textattack
#     Found existing installation: textattack 0.3.9
#     Uninstalling textattack-0.3.9:
#       Successfully uninstalled textattack-0.3.9
#   Running setup.py develop for textattack
# ...

# %%
# !textattack peek-dataset --dataset-from-huggingface rotten_tomatoes
# Out:
# 2023-12-17 15:26:34.879628: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 15:26:34.879689: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 15:26:34.881097: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 15:26:36.416989: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Generating train split: 100% 8530/8530 [00:00<00:00, 26558.50 examples/s]
# Generating validation split: 100% 1066/1066 [00:00<00:00, 19239.35 examples/s]
# Generating test split: 100% 1066/1066 [00:00<00:00, 21551.24 examples/s]
# ...

# %%
# !textattack train --model-name-or-path lstm --dataset rotten_tomatoes --model-num-labels 2 --model-max-length 64 --per-device-train-batch-size 128 --num-epochs 10
# Out:
# 2023-12-17 15:27:43.268193: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 15:27:43.268264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 15:27:43.269936: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 15:27:44.623872: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading textattack model: LSTMForClassification
# textattack: Downloading https://textattack.s3.amazonaws.com/word_embeddings/glove200.
# 100% 389M/389M [00:10<00:00, 35.6MB/s]
# ...

# %%
# !textattack eval --num-examples 1000 --model ./outputs/2023-12-17-15-27-49-630742/best_model/ --dataset-from-huggingface rotten_tomatoes --dataset-split test
# Out:
# 2023-12-17 15:50:07.783702: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 15:50:07.783775: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 15:50:07.786131: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 15:50:09.463737: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/usr/local/bin/textattack", line 33, in <module>
#     sys.exit(load_entry_point('textattack', 'console_scripts', 'textattack')())
# ...

# %%
# %cd myproject/TextAttack/
# Out:
# /content/myproject/TextAttack

# %%
# !pwd
# Out:
# /content/myproject/TextAttack

# %%
# !pip install -e .
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.10/dist-packages)
# Obtaining file:///content/myproject/TextAttack
#   Preparing metadata (setup.py) ... done
#   WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.10/dist-packages)
# ...
#   Attempting uninstall: textattack
#     WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.10/dist-packages)
#     Found existing installation: textattack 0.3.9
#     Uninstalling textattack-0.3.9:
#       Successfully uninstalled textattack-0.3.9
#   Running setup.py develop for textattack
# WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.10/dist-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/usr/local/lib/python3.10/dist-packages)
# ...

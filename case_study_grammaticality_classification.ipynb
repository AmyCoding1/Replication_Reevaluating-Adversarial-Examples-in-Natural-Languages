# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install language_tool_python --upgrade
# Out:
# Requirement already satisfied: language_tool_python in /usr/local/lib/python3.10/dist-packages (2.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from language_tool_python) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from language_tool_python) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->language_tool_python) (2023.11.17)

# %%
import language_tool_python
import pandas as pd
from io import StringIO

from tqdm import tqdm
tqdm.pandas()

# %%
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
data_path = '/content/drive/MyDrive/Project_AI/Replication-NLP-Adversarial-Examples-master/section_3_case_study/case_study_examples.csv'
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#         dataset  original_class  \
# 0  movie_review             1.0
# 1  movie_review             1.0
# 2  movie_review             1.0
# 3  movie_review             1.0
# 4  movie_review             1.0
#
#                                        original_text  perturbed_class  \
# 0  [[lovingly]] photographed in the manner of a g...              0.0
# 1  [[consistently]] [[clever]] and [[suspenseful]] .              1.0
# 2  it's like a " big chill " reunion of the baade...              0.0
# 3  the story gives ample opportunity for large-sc...              0.0
# 4              red dragon " never cuts [[corners]] .              0.0
#
#                                       perturbed_text run_type
# 0  [[clumsily]] photographed in the manner of a g...      jin
# 1     [[necessarily]] [[malin]] and [[suggestive]] .      jin
# 2  it's like a " big chill " reunion of the baade...      jin
# 3  the story gives ample opportunity for large-sc...      jin
# 4               red dragon " never cuts [[angles]] .      jin

# %%
lang_tool = language_tool_python.LanguageTool("en-US")

# %%
def get_errors(text):
    return lang_tool.check(text)

def get_error_count(text):
    return len(get_errors(text))

# %%
df['original_text_errors'] = df['original_text'].progress_map(get_errors)
df['perturbed_text_errors'] = df['perturbed_text'].progress_map(get_errors)
# Out:
# 100%|██████████| 3292/3292 [04:28<00:00, 12.26it/s]
# 100%|██████████| 3292/3292 [03:57<00:00, 13.88it/s]

# %%
df['original_text_error_count'] = df['original_text_errors'].map(len)
df['perturbed_text_error_count'] = df['perturbed_text_errors'].map(len)

# %%
original_text_errors = [e for l in df['original_text_errors'] for e in l]
perturbed_text_errors = [e for l in df['perturbed_text_errors'] for e in l]
print('Original errors:', len(original_text_errors))
print('Perturbed errors:', len(perturbed_text_errors))
# Out:
# Original errors: 4494
# Perturbed errors: 4570

# %%
print('Added errors:', (df['original_text_error_count'] < df['perturbed_text_error_count']).sum())
print('Same # errors:', (df['original_text_error_count'] == df['perturbed_text_error_count']).sum())
print('Removed errors:', (df['original_text_error_count'] > df['perturbed_text_error_count']).sum())
# Out:
# Added errors: 66
# Same # errors: 3226
# Removed errors: 0

# %%
df['run'] = df['dataset'] + '_' + df['run_type']
print(df['run'].unique())
# Out:
# ['movie_review_jin' nan]

# %%
original_text_error_rule_ids = pd.Series([x.ruleId for x in original_text_errors])
perturbed_text_error_rule_ids = pd.Series([x.ruleId for x in perturbed_text_errors])

original_text_error_rule_freqs = original_text_error_rule_ids.value_counts().to_dict()
perturbed_text_error_rule_freqs = perturbed_text_error_rule_ids.value_counts().to_dict()

print('Original errors:', original_text_error_rule_ids.value_counts())
print()
print('Perturbed errors:', perturbed_text_error_rule_ids.value_counts())
# Out:
# Original errors: MORFOLOGIK_RULE_EN_US           3122
# COMMA_PARENTHESIS_WHITESPACE     906
# UPPERCASE_SENTENCE_START         408
# EN_SPECIFIC_CASE                  18
# I_LOWERCASE                       12
# EN_COMPOUNDS                       4
# EN_UNPAIRED_BRACKETS               4
# VERB_APOSTROPHE_S                  2
# EN_DIACRITICS_REPLACE              2
# A_UNCOUNTABLE                      2
# CONFUSION_OF_MARS_MARS             2
# ADVERB_WORD_ORDER                  2
# ARTICLE_ADJECTIVE_OF               2
# MUCH_NEEDED_HYPHEN                 2
# SOME_OF_THE                        2
# WHETHER                            2
# ENGLISH_WORD_REPEAT_RULE           2
# dtype: int64
#
# Perturbed errors: MORFOLOGIK_RULE_EN_US           3192
# COMMA_PARENTHESIS_WHITESPACE     906
# UPPERCASE_SENTENCE_START         408
# EN_SPECIFIC_CASE                  18
# I_LOWERCASE                       12
# EN_COMPOUNDS                       4
# EN_UNPAIRED_BRACKETS               4
# ID_CASING                          2
# WHETHER                            2
# SOME_OF_THE                        2
# BESTEST                            2
# MUCH_NEEDED_HYPHEN                 2
# CONFUSION_OF_MARS_MARS             2
# ARTICLE_ADJECTIVE_OF               2
# ADVERB_WORD_ORDER                  2
# A_UNCOUNTABLE                      2
# EN_DIACRITICS_REPLACE              2
# VERB_APOSTROPHE_S                  2
# AI                                 2
# ENGLISH_WORD_REPEAT_RULE           2
# dtype: int64

# %%
err_data = []

for rule_id, pert_freq in perturbed_text_error_rule_freqs.items():
    orig_freq = original_text_error_rule_freqs.get(rule_id, 0)
    freq_diff = pert_freq - orig_freq
    freq_ratio = pert_freq / orig_freq if orig_freq else None
    err_data.append({
        'freq_diff':  freq_diff,
        'orig_freq':  orig_freq,
        'pert_freq':  pert_freq,
        'freq_ratio': freq_ratio,
        'rule_id': rule_id
    })

err_data = pd.DataFrame(err_data)
err_data['freq_diff_perc'] = err_data['freq_diff'] / float(len(df))
err_data.head()
# Out:
#    freq_diff  orig_freq  pert_freq  freq_ratio                       rule_id  \
# 0         70       3122       3192    1.022422         MORFOLOGIK_RULE_EN_US
# 1          0        906        906    1.000000  COMMA_PARENTHESIS_WHITESPACE
# 2          0        408        408    1.000000      UPPERCASE_SENTENCE_START
# 3          0         18         18    1.000000              EN_SPECIFIC_CASE
# 4          0         12         12    1.000000                   I_LOWERCASE
#
#    freq_diff_perc
# 0        0.021264
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000

# %%
len(df)
# Out:
# 3292

# %%
pd.set_option('display.max_rows', None)

err_data.sort_values(by='freq_diff', ascending=False)
# Out:
#     freq_diff  orig_freq  pert_freq  freq_ratio                       rule_id  \
# 0          70       3122       3192    1.022422         MORFOLOGIK_RULE_EN_US
# 7           2          0          2         NaN                     ID_CASING
# 18          2          0          2         NaN                            AI
# 10          2          0          2         NaN                       BESTEST
# 4           0         12         12    1.000000                   I_LOWERCASE
# 5           0          4          4    1.000000                  EN_COMPOUNDS
# 6           0          4          4    1.000000          EN_UNPAIRED_BRACKETS
# 3           0         18         18    1.000000              EN_SPECIFIC_CASE
# 8           0          2          2    1.000000                       WHETHER
# 9           0          2          2    1.000000                   SOME_OF_THE
# 1           0        906        906    1.000000  COMMA_PARENTHESIS_WHITESPACE
# 11          0          2          2    1.000000            MUCH_NEEDED_HYPHEN
# 12          0          2          2    1.000000        CONFUSION_OF_MARS_MARS
# 13          0          2          2    1.000000          ARTICLE_ADJECTIVE_OF
# 14          0          2          2    1.000000             ADVERB_WORD_ORDER
# 15          0          2          2    1.000000                 A_UNCOUNTABLE
# 16          0          2          2    1.000000         EN_DIACRITICS_REPLACE
# 17          0          2          2    1.000000             VERB_APOSTROPHE_S
# 2           0        408        408    1.000000      UPPERCASE_SENTENCE_START
# 19          0          2          2    1.000000      ENGLISH_WORD_REPEAT_RULE
#
#     freq_diff_perc
# 0         0.021264
# 7         0.000608
# 18        0.000608
# 10        0.000608
# 4         0.000000
# 5         0.000000
# 6         0.000000
# 3         0.000000
# 8         0.000000
# 9         0.000000
# 1         0.000000
# 11        0.000000
# 12        0.000000
# 13        0.000000
# 14        0.000000
# 15        0.000000
# 16        0.000000
# 17        0.000000
# 2         0.000000
# 19        0.000000

# %%
err_data[err_data['freq_ratio'].isna()].sort_values(by='freq_diff', ascending=False)
# Out:
#     freq_diff  orig_freq  pert_freq  freq_ratio    rule_id  freq_diff_perc
# 7           2          0          2         NaN  ID_CASING        0.000608
# 10          2          0          2         NaN    BESTEST        0.000608
# 18          2          0          2         NaN         AI        0.000608

# %%
err_data.sort_values(by=['pert_freq'], ascending=False)
# Out:
#     freq_diff  orig_freq  pert_freq  freq_ratio                       rule_id  \
# 0          70       3122       3192    1.022422         MORFOLOGIK_RULE_EN_US
# 1           0        906        906    1.000000  COMMA_PARENTHESIS_WHITESPACE
# 2           0        408        408    1.000000      UPPERCASE_SENTENCE_START
# 3           0         18         18    1.000000              EN_SPECIFIC_CASE
# 4           0         12         12    1.000000                   I_LOWERCASE
# 5           0          4          4    1.000000                  EN_COMPOUNDS
# 6           0          4          4    1.000000          EN_UNPAIRED_BRACKETS
# 13          0          2          2    1.000000          ARTICLE_ADJECTIVE_OF
# 18          2          0          2         NaN                            AI
# 17          0          2          2    1.000000             VERB_APOSTROPHE_S
# 16          0          2          2    1.000000         EN_DIACRITICS_REPLACE
# 15          0          2          2    1.000000                 A_UNCOUNTABLE
# 14          0          2          2    1.000000             ADVERB_WORD_ORDER
# 10          2          0          2         NaN                       BESTEST
# 12          0          2          2    1.000000        CONFUSION_OF_MARS_MARS
# 11          0          2          2    1.000000            MUCH_NEEDED_HYPHEN
# 9           0          2          2    1.000000                   SOME_OF_THE
# 8           0          2          2    1.000000                       WHETHER
# 7           2          0          2         NaN                     ID_CASING
# 19          0          2          2    1.000000      ENGLISH_WORD_REPEAT_RULE
#
#     freq_diff_perc
# 0         0.021264
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
# 5         0.000000
# 6         0.000000
# 13        0.000000
# 18        0.000608
# 17        0.000000
# 16        0.000000
# 15        0.000000
# 14        0.000000
# 10        0.000608
# 12        0.000000
# 11        0.000000
# 9         0.000000
# 8         0.000000
# 7         0.000608
# 19        0.000000

# %%
len(df)
# Out:
# 3292

# %%
err_data.sort_values(by=['freq_ratio', 'freq_diff'], ascending=False)
# Out:
#     freq_diff  orig_freq  pert_freq  freq_ratio                       rule_id  \
# 0          70       3122       3192    1.022422         MORFOLOGIK_RULE_EN_US
# 1           0        906        906    1.000000  COMMA_PARENTHESIS_WHITESPACE
# 2           0        408        408    1.000000      UPPERCASE_SENTENCE_START
# 3           0         18         18    1.000000              EN_SPECIFIC_CASE
# 4           0         12         12    1.000000                   I_LOWERCASE
# 5           0          4          4    1.000000                  EN_COMPOUNDS
# 6           0          4          4    1.000000          EN_UNPAIRED_BRACKETS
# 8           0          2          2    1.000000                       WHETHER
# 9           0          2          2    1.000000                   SOME_OF_THE
# 11          0          2          2    1.000000            MUCH_NEEDED_HYPHEN
# 12          0          2          2    1.000000        CONFUSION_OF_MARS_MARS
# 13          0          2          2    1.000000          ARTICLE_ADJECTIVE_OF
# 14          0          2          2    1.000000             ADVERB_WORD_ORDER
# 15          0          2          2    1.000000                 A_UNCOUNTABLE
# 16          0          2          2    1.000000         EN_DIACRITICS_REPLACE
# 17          0          2          2    1.000000             VERB_APOSTROPHE_S
# 19          0          2          2    1.000000      ENGLISH_WORD_REPEAT_RULE
# 7           2          0          2         NaN                     ID_CASING
# 10          2          0          2         NaN                       BESTEST
# 18          2          0          2         NaN                            AI
#
#     freq_diff_perc
# 0         0.021264
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
# 5         0.000000
# 6         0.000000
# 8         0.000000
# 9         0.000000
# 11        0.000000
# 12        0.000000
# 13        0.000000
# 14        0.000000
# 15        0.000000
# 16        0.000000
# 17        0.000000
# 19        0.000000
# 7         0.000608
# 10        0.000608
# 18        0.000608

# %%
perturbed_text_errors[0]
# Out:
# Match({'ruleId': 'COMMA_PARENTHESIS_WHITESPACE', 'message': 'Put a space after the comma, but not before the comma.', 'replacements': [','], 'offsetInContext': 43, 'context': '...e manner of a golden book sprung to life , stuart little 2 manages sweetness large...', 'offset': 71, 'errorLength': 2, 'category': 'TYPOGRAPHY', 'ruleIssueType': 'whitespace', 'sentence': '[[clumsily]] photographed in the manner of a golden book sprung to life , stuart little 2 manages sweetness largely without stickiness .'})

# %%
for err in perturbed_text_errors:
    if err.ruleId == 'MORFOLOGIK_RULE_EN_US':
        badword = err.context[err.offset:err.offset+err.errorLength]
        goodwords = err.replacements
        print(err.message + ':', 'Replace',badword,'with one of',goodwords)
        print(err.category)
        print()
        break
# Out:
# Possible spelling mistake found.: Replace ss lar with one of ['Stuart', 'start', 'Stuarts', 'square', 'star', 'stars', 'starts', 'Stewart', 'smart', 'estuary', 'stunt', 'Stark', 'Starr', 'stark', 'strait', 'Surat', 'squat', 'stare', 'stat', 'spurt', 'tart', 'quart', 'squirt', 'stoat', 'Seurat', 'SART', 'SMART', 'STAR', 'STARS', 'STAAR']
# TYPOS

# %%
def yield_errs(err_code, num_to_print=1):
    n = 0
    for err in perturbed_text_errors:
        if n >= num_to_print:
            break
        if err.ruleId == err_code:
            print('err:', err)
            badword = err.context[err.offset:err.offset+err.errorLength]
            goodwords = err.replacements
            err_str = err_code + ': ' + err.message + ' || Replace '+badword+' with one of ' + '[' +','.join(goodwords) + ']'
            context = err.context
            cat = err.category
            yield err_str
            n += 1

def get_err(err_code):
    ans = list(yield_errs(err_code, num_to_print=1))
    return ans[0] if len(ans) else None

def get_errs(*args):
    return list(yield_errs(*args))

def print_errs(*args):
    print(get_errs(*args))

print_errs('I_AM')
# Out:
# []

# %%
def yield_errs_context(err_code, num_to_print=1):
    n = 0
    for err in perturbed_text_errors:
        if n >= num_to_print:
            break
        if err.ruleId == err_code:
            badword = err.context[err.offset:err.offset+err.errorLength]
            goodwords = err.replacements
            err_str = err_code + ': ' + err.message + ' || Replace '+badword+' with one of ' + '[' +','.join(goodwords) + ']'
            context = err.context
            cat = err.category
            yield context
            n += 1

def get_err_context(err_code):
    ans = list(yield_errs_context(err_code, num_to_print=1))
    return ans[0] if len(ans) else None

def get_errs_context(*args):
    return list(yield_errs_context(*args))

def print_errs_context(*args):
    print(get_errs_context(*args))

print_errs('I_AM')
# Out:
# []

# %%
get_err('DID_BASEFORM')

# %%
get_errs('DID_BASEFORM', 20)
# Out:
# []

# %%
pd.options.display.max_colwidth = 500
err_data['Explanation'] = err_data['rule_id'].map(get_err)
err_data['Context'] = err_data['rule_id'].map(get_err_context)
err_data.head()
# Out:
# err: Offset 74, length 6, Rule ID: MORFOLOGIK_RULE_EN_US
# Message: Possible spelling mistake found.
# Suggestion: Stuart; start; Stuarts; square; star; stars; starts; Stewart; smart; estuary; stunt; Stark; Starr; stark; strait; Surat; squat; stare; stat; spurt; tart; quart; squirt; stoat; Seurat; SART; SMART; STAR; STARS; STAAR
# ...anner of a golden book sprung to life , stuart little 2 manages sweetness largely with...
#                                            ^^^^^^
# err: Offset 71, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ...e manner of a golden book sprung to life , stuart little 2 manages sweetness large...
#                                            ^^
# err: Offset 0, length 2, Rule ID: UPPERCASE_SENTENCE_START
# Message: This sentence does not start with an uppercase letter.
# Suggestion: It
# it's like a " big chill " reunion of the b...
# ^^
# err: Offset 12, length 9, Rule ID: EN_SPECIFIC_CASE
# Message: If the term is a proper noun, use initial capitals.
# Suggestion: Star Trek
# devotees of star trek ii : the wrath of khan will feel a nagg...
#             ^^^^^^^^^
# err: Offset 4, length 1, Rule ID: I_LOWERCASE
# Message: The personal pronoun “I” should be uppercase.
# Suggestion: I
# can i admit xxx is as deep as a petri dish an...
#     ^
# err: Offset 43, length 13, Rule ID: EN_COMPOUNDS
# Message: This word is normally spelled with a hyphen.
# Suggestion: old-fashioned
# ... . quite good at [[provided]] some good old fashioned spooks .
#                                            ^^^^^^^^^^^^^
# err: Offset 122, length 1, Rule ID: EN_UNPAIRED_BRACKETS
# Message: Unpaired symbol: ‘"’ seems to be missing
# ...d dark , funny [[travesty]] [[offer]] " " the [[bestest]] [[nana]] " a film [[cha...
#                                            ^
# err: Offset 130, length 3, Rule ID: ID_CASING
# Message: This abbreviation for “identification” is spelled all-uppercase.
# Suggestion: IDs
# ..., unfussily poetic [[meditate]] about [[ids]] and alienation .
#                                            ^^^
# err: Offset 0, length 14, Rule ID: WHETHER
# Message: Consider shortening this phrase to just “whether”. It is correct though if you mean ‘regardless of whether’.
# Suggestion: whether
# whether or not ram [[zum]] proves as clear and reliabl...
# ^^^^^^^^^^^^^^
# err: Offset 8, length 11, Rule ID: SOME_OF_THE
# Message: If the text is a generality, ‘of the’ is not necessary.
# Suggestion: some
# it uses some of the figures from the real-life story to por...
#         ^^^^^^^^^^^
# err: Offset 130, length 7, Rule ID: BESTEST
# Message: The word “bestest” is informal.
# Suggestion: best
# ... funny [[travesty]] [[offer]] " " the [[bestest]] [[nana]] " a film [[chastisement]] wa...
#                                            ^^^^^^^
# err: Offset 180, length 11, Rule ID: MUCH_NEEDED_HYPHEN
# Message: When “much-needed” is used as a modifier, it is usually spelled with a hyphen.
# Suggestion: much-needed
# ...nt past and south korea's future adds a much needed moral weight .
#                                            ^^^^^^^^^^^
# err: Offset 96, length 4, Rule ID: CONFUSION_OF_MARS_MARS
# Message: The planet, chocolate brand and the god are written with uppercase. ‘mars’ refers to the verb ‘mar’ meaning to spoil, or the plural of the noun ‘mar’ meaning blemishes.
# Suggestion: Mars
# ...esis that women from venus and men from mars can indeed get together .
#                                            ^^^^
# err: Offset 79, length 12, Rule ID: ARTICLE_ADJECTIVE_OF
# Message: The phrase ‘the soullessness of’ is not correct. Use a noun, not an adjective, between ‘the’ and ‘of’.
# ...ul]] and mordantly humorous take on the soullessness of work in the [[midtown]] .
#                                            ^^^^^^^^^^^^
# err: Offset 10, length 12, Rule ID: ADVERB_WORD_ORDER
# Message: The adverb ‘sometimes’ usually goes after the verb ‘is’.
# Suggestion: is sometimes
# charlotte sometimes is a gem . it's always [[hallucinatory]] ....
#           ^^^^^^^^^^^^
# err: Offset 73, length 21, Rule ID: A_UNCOUNTABLE
# Message: Uncountable nouns are usually not used with an indefinite article. Use simply “casual intelligence”.
# Suggestion: casual intelligence
# ...odger . but what's nice is that there's a casual intelligence that [[infiltrates]] the script .
#                                            ^^^^^^^^^^^^^^^^^^^^^
# err: Offset 74, length 7, Rule ID: EN_DIACRITICS_REPLACE
# Message: ‘deja vu’ is an imported foreign name or expression, which originally has a diacritic.
# Suggestion: déjà vu
# ...th of khan will feel a nagging sense of deja vu , and the grandeur of the best next gen...
#                                            ^^^^^^^
# err: Offset 205, length 7, Rule ID: VERB_APOSTROPHE_S
# Message: Do not use ’s with a verb.
# Suggestion: welshes
# ...ch itself felt like an answer to irvine welsh's book trainspotting .
#                                            ^^^^^^^
# err: Offset 158, length 2, Rule ID: AI
# Message: For abbreviations such as ‘artificial intelligence’, use all capital letters. The rare word ‘ai’ is a synonym for ‘three-toed sloth’.
# Suggestion: AI
# ...at we [[actually]] [[knowledge]] what [[ai]] holly and marina [[check]] , and our ...
#                                            ^^
# err: Offset 45, length 5, Rule ID: ENGLISH_WORD_REPEAT_RULE
# Message: Possible typo: you repeated a word
# Suggestion: yi
# ... strike against yang's similarly themed yi yi , but i [[discover]] what time ? to be ...
#                                            ^^^^^
#    freq_diff  orig_freq  pert_freq  freq_ratio                       rule_id  \
# 0         70       3122       3192    1.022422         MORFOLOGIK_RULE_EN_US
# 1          0        906        906    1.000000  COMMA_PARENTHESIS_WHITESPACE
# 2          0        408        408    1.000000      UPPERCASE_SENTENCE_START
# 3          0         18         18    1.000000              EN_SPECIFIC_CASE
# 4          0         12         12    1.000000                   I_LOWERCASE
#
#    freq_diff_perc  \
# 0        0.021264
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#
#                                                                                                                                                                                                                                                                           Explanation  \
# 0  MORFOLOGIK_RULE_EN_US: Possible spelling mistake found. || Replace ss lar with one of [Stuart,start,Stuarts,square,star,stars,starts,Stewart,smart,estuary,stunt,Stark,Starr,stark,strait,Surat,squat,stare,stat,spurt,tart,quart,squirt,stoat,Seurat,SART,SMART,STAR,STARS,STAAR]
# 1                                                                                                                                                                  COMMA_PARENTHESIS_WHITESPACE: Put a space after the comma, but not before the comma. || Replace we with one of [,]
# 2                                                                                                                                                                     UPPERCASE_SENTENCE_START: This sentence does not start with an uppercase letter. || Replace it with one of [It]
# 3                                                                                                                                                                  EN_SPECIFIC_CASE: If the term is a proper noun, use initial capitals. || Replace star trek with one of [Star Trek]
# 4                                                                                                                                                                                             I_LOWERCASE: The personal pronoun “I” should be uppercase. || Replace i with one of [I]
#
#                                                                                         Context
# 0  ...anner of a golden book sprung to life , stuart little 2 manages sweetness largely with...
# 1      ...e manner of a golden book sprung to life , stuart little 2 manages sweetness large...
# 2                                                 it's like a " big chill " reunion of the b...
# 3                              devotees of star trek ii : the wrath of khan will feel a nagg...
# 4                                              can i admit xxx is as deep as a petri dish an...

# %%
err_data.sort_values(by=['freq_ratio','freq_diff'], ascending=False)
# Out:
#     freq_diff  orig_freq  pert_freq  freq_ratio                       rule_id  \
# 0          70       3122       3192    1.022422         MORFOLOGIK_RULE_EN_US
# 1           0        906        906    1.000000  COMMA_PARENTHESIS_WHITESPACE
# 2           0        408        408    1.000000      UPPERCASE_SENTENCE_START
# 3           0         18         18    1.000000              EN_SPECIFIC_CASE
# 4           0         12         12    1.000000                   I_LOWERCASE
# 5           0          4          4    1.000000                  EN_COMPOUNDS
# 6           0          4          4    1.000000          EN_UNPAIRED_BRACKETS
# 8           0          2          2    1.000000                       WHETHER
# 9           0          2          2    1.000000                   SOME_OF_THE
# 11          0          2          2    1.000000            MUCH_NEEDED_HYPHEN
# 12          0          2          2    1.000000        CONFUSION_OF_MARS_MARS
# 13          0          2          2    1.000000          ARTICLE_ADJECTIVE_OF
# 14          0          2          2    1.000000             ADVERB_WORD_ORDER
# 15          0          2          2    1.000000                 A_UNCOUNTABLE
# 16          0          2          2    1.000000         EN_DIACRITICS_REPLACE
# 17          0          2          2    1.000000             VERB_APOSTROPHE_S
# 19          0          2          2    1.000000      ENGLISH_WORD_REPEAT_RULE
# 7           2          0          2         NaN                     ID_CASING
# 10          2          0          2         NaN                       BESTEST
# 18          2          0          2         NaN                            AI
#
#     freq_diff_perc  \
# 0         0.021264
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
# 5         0.000000
# 6         0.000000
# 8         0.000000
# 9         0.000000
# 11        0.000000
# 12        0.000000
# 13        0.000000
# 14        0.000000
# 15        0.000000
# 16        0.000000
# 17        0.000000
# 19        0.000000
# 7         0.000608
# 10        0.000608
# 18        0.000608
#
#                                                                                                                                                                                                                                                                            Explanation  \
# 0   MORFOLOGIK_RULE_EN_US: Possible spelling mistake found. || Replace ss lar with one of [Stuart,start,Stuarts,square,star,stars,starts,Stewart,smart,estuary,stunt,Stark,Starr,stark,strait,Surat,squat,stare,stat,spurt,tart,quart,squirt,stoat,Seurat,SART,SMART,STAR,STARS,STAAR]
# 1                                                                                                                                                                   COMMA_PARENTHESIS_WHITESPACE: Put a space after the comma, but not before the comma. || Replace we with one of [,]
# 2                                                                                                                                                                      UPPERCASE_SENTENCE_START: This sentence does not start with an uppercase letter. || Replace it with one of [It]
# 3                                                                                                                                                                   EN_SPECIFIC_CASE: If the term is a proper noun, use initial capitals. || Replace star trek with one of [Star Trek]
# 4                                                                                                                                                                                              I_LOWERCASE: The personal pronoun “I” should be uppercase. || Replace i with one of [I]
# 5                                                                                                                                                                      EN_COMPOUNDS: This word is normally spelled with a hyphen. || Replace old fashioned with one of [old-fashioned]
# 6                                                                                                                                                                                            EN_UNPAIRED_BRACKETS: Unpaired symbol: ‘"’ seems to be missing || Replace  with one of []
# 8                                                                                                                WHETHER: Consider shortening this phrase to just “whether”. It is correct though if you mean ‘regardless of whether’. || Replace whether or not with one of [whether]
# 9                                                                                                                                                                       SOME_OF_THE: If the text is a generality, ‘of the’ is not necessary. || Replace some of the with one of [some]
# 11                                                                                                                                            MUCH_NEEDED_HYPHEN: When “much-needed” is used as a modifier, it is usually spelled with a hyphen. || Replace  with one of [much-needed]
# 12                                                     CONFUSION_OF_MARS_MARS: The planet, chocolate brand and the god are written with uppercase. ‘mars’ refers to the verb ‘mar’ meaning to spoil, or the plural of the noun ‘mar’ meaning blemishes. || Replace  with one of [Mars]
# 13                                                                                                                        ARTICLE_ADJECTIVE_OF: The phrase ‘the soullessness of’ is not correct. Use a noun, not an adjective, between ‘the’ and ‘of’. || Replace n]] . with one of []
# 14                                                                                                                                                      ADVERB_WORD_ORDER: The adverb ‘sometimes’ usually goes after the verb ‘is’. || Replace sometimes is with one of [is sometimes]
# 15                                                                                              A_UNCOUNTABLE: Uncountable nouns are usually not used with an indefinite article. Use simply “casual intelligence”. || Replace nfiltrates]] the scri with one of [casual intelligence]
# 16                                                                                                                              EN_DIACRITICS_REPLACE: ‘deja vu’ is an imported foreign name or expression, which originally has a diacritic. || Replace he best with one of [déjà vu]
# 17                                                                                                                                                                                                     VERB_APOSTROPHE_S: Do not use ’s with a verb. || Replace  with one of [welshes]
# 19                                                                                                                                                                                      ENGLISH_WORD_REPEAT_RULE: Possible typo: you repeated a word || Replace  yi , with one of [yi]
# 7                                                                                                                                                                            ID_CASING: This abbreviation for “identification” is spelled all-uppercase. || Replace  with one of [IDs]
# 10                                                                                                                                                                                                             BESTEST: The word “bestest” is informal. || Replace  with one of [best]
# 18                                                                                                              AI: For abbreviations such as ‘artificial intelligence’, use all capital letters. The rare word ‘ai’ is a synonym for ‘three-toed sloth’. || Replace  with one of [AI]
#
#                                                                                                Context
# 0         ...anner of a golden book sprung to life , stuart little 2 manages sweetness largely with...
# 1             ...e manner of a golden book sprung to life , stuart little 2 manages sweetness large...
# 2                                                        it's like a " big chill " reunion of the b...
# 3                                     devotees of star trek ii : the wrath of khan will feel a nagg...
# 4                                                     can i admit xxx is as deep as a petri dish an...
# 5                                    ... . quite good at [[provided]] some good old fashioned spooks .
# 6              ...d dark , funny [[travesty]] [[offer]] " " the [[bestest]] [[nana]] " a film [[cha...
# 8                                            whether or not ram [[zum]] proves as clear and reliabl...
# 9                                       it uses some of the figures from the real-life story to por...
# 11                               ...nt past and south korea's future adds a much needed moral weight .
# 12                           ...esis that women from venus and men from mars can indeed get together .
# 13                ...ul]] and mordantly humorous take on the soullessness of work in the [[midtown]] .
# 14                                   charlotte sometimes is a gem . it's always [[hallucinatory]] ....
# 15  ...odger . but what's nice is that there's a casual intelligence that [[infiltrates]] the script .
# 16       ...th of khan will feel a nagging sense of deja vu , and the grandeur of the best next gen...
# 17                             ...ch itself felt like an answer to irvine welsh's book trainspotting .
# 19         ... strike against yang's similarly themed yi yi , but i [[discover]] what time ? to be ...
# 7                                    ..., unfussily poetic [[meditate]] about [[ids]] and alienation .
# 10       ... funny [[travesty]] [[offer]] " " the [[bestest]] [[nana]] " a film [[chastisement]] wa...
# 18            ...at we [[actually]] [[knowledge]] what [[ai]] holly and marina [[check]] , and our ...

# %%
min_pert_freq = 25
min_pert_ratio = 5.0


explanatory_df = err_data \
    [(err_data['pert_freq'] > min_pert_freq) & (err_data['freq_ratio'] > min_pert_ratio)] \
    .sort_values(by=['freq_ratio','freq_diff'], ascending=False) \
    .reset_index() \
    .drop(['freq_ratio', 'freq_diff', 'index', 'freq_diff_perc'], axis=1)

explanatory_df = explanatory_df[['rule_id', 'orig_freq', 'pert_freq', 'Explanation', 'Context']]
explanatory_df.head()
# Out:
# Empty DataFrame
# Columns: [rule_id, orig_freq, pert_freq, Explanation, Context]
# Index: []

# %%
latex = explanatory_df.to_latex()
for line in latex.split('\n'):
    print(line)
# Out:
# <ipython-input-48-ecdd026a9585>:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   latex = explanatory_df.to_latex()
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-48-ecdd026a9585> in <cell line: 1>()
# ----> 1 latex = explanatory_df.to_latex()
#       2 for line in latex.split('\n'):
#       3     print(line)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_latex(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, bold_rows, column_format, longtable, escape, encoding, decimal, multicolumn, multicolumn_format, multirow, caption, label, position)
#    3467         Convert a general DataFrame to LaTeX with formatting:
#    3468
# -> 3469         >>> df = pd.DataFrame(dict(name=['Raphael', 'Donatello'],
#    3470         ...                        age=[26, 45],
#    3471         ...                        height=[181.23, 177.65]))
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_latex(self, buf, column_format, longtable, encoding, multicolumn, multicolumn_format, multirow, caption, label, position)
#    1044             returned as a string.
#    1045         encoding : str, default “utf-8”
# -> 1046             Set character encoding.
#    1047         classes : str or list-like
#    1048             classes to include in the `class` attribute of the opening
#
# ModuleNotFoundError: No module named 'pandas.io.formats.latex'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df['run'].unique()
# Out:
# array(['movie_review_jin', nan], dtype=object)

# %%
len(df)
# Out:
# 3292

# %%
df['introduced_error'] = df['original_text_error_count'] < df['perturbed_text_error_count']
df.groupby('run')['introduced_error'].mean()
# Out:
# run
# movie_review_jin    0.165
# Name: introduced_error, dtype: float64

# %%
df['introduced_error'].mean()
# Out:
# 0.020048602673147023
